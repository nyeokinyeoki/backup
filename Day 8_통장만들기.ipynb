# %%
class Account(object) :
    # 객체의 속성 초기화
    def __init__(self, custId, custName, accountNumber, balance) : 
        self.custId = custId
        self.custName = custName
        self.accountNumber = accountNumber
        self.balance = balance
    
    def printBalance(self) : 
        print("======================")
        print("현재 잔액 : {}".format(self.balance))
        print("======================")
               
    def addBalance(self, balance) : 
        print("{} 원을 입금합니다.".format(balance))
        if balance <= 0 : 
            print("금액 오류입니다. : {}".format(balance))
        else : 
            self.balance += balance
            self.printBalance()
            
    def substractBalance(self, balance) : 
        print("{} 원을 출금합니다.".format(balance))
        if self.balance < balance : 
            print("출금 불가!! 잔고가 부족합니다.")
        else : 
            self.balance -= balance
            self.printBalance()
                   
    def printAccount(self) : 
        print("=====================================")
        print("고객번호 : {}, 고객명 : {}\n계좌번호 : {}, 잔액 : {} 원".format(self.custId,self.custName,self.accountNumber,self.balance))            
        print("=====================================")
                    
    @staticmethod    
    def getMenuItem() : 
        print("1. 입금\n2. 출금\n9. 종료")
        menu_input = int(input("=> Menu 선택 : "))
        return menu_input
    
    @staticmethod    
    def getAccount() : 
        insertMoney = int(input("금액 : "))
        return insertMoney
        
## 객체 생성 후
cust1 = Account("CUST01", "소지섭", "1-22-333", 100000)
cust1.printAccount()
while True : 
    menu = Account.getMenuItem()
    if menu == 9 : 
        print("Bye~~")
        break
    elif menu == 1 : 
        balance = Account.getAccount()
        cust1.addBalance(balance)
    elif menu == 2 : 
        balance = Account.getAccount()
        cust1.substractBalance(balance)
# Out:
# =====================================
# 고객번호 : CUST01, 고객명 : 소지섭
# 계좌번호 : 1-22-333, 잔액 : 100000 원
# =====================================
# 1. 입금
# 2. 출금
# 9. 종료
# => Menu 선택 : 1
# 금액 : 0
# 0 원을 입금합니다.
# 금액 오류입니다. : 0
# 1. 입금
# 2. 출금
# 9. 종료
# => Menu 선택 : 2
# 금액 : 105000
# 105000 원을 출금합니다.
# 출금 불가!! 잔고가 부족합니다.
# 1. 입금
# 2. 출금
# 9. 종료
# => Menu 선택 : 2
# 금액 : 50000
# 50000 원을 출금합니다.
# ======================
# 현재 잔액 : 50000
# ======================
# 1. 입금
# 2. 출금
# 9. 종료

# %%
class Account(object) :
    def __init__(self, custId, custName, accountNumber, balance) :   #객체의 속성 초기화
        self.custId = custId
        self.custName = custName
        self.accountNumber = accountNumber
        self.balance = balance

    def addBalance(self, balance) :
        print("{}원을 입금합니다.".format(balance))
        if balance <= 0 :
            print("금액 오류입니다. :  {} 원".format(balance))
        else :
            print("{} 원을 입금합니다.".format(balance))
            self.balance += balance
            self.printBalance()

    def substractBalance(self, balance) :
        print("{}원을 출금합니다.".format(balance))
        if self.balance < balance : 
             print("출금불가!! 잔고가 부족합니다.")
        else :
            self.balance -= balance
            self.printBalance()
    def printBalance(self):
        print("=================")
        print("현재 잔액 : {}".format(self.balance))
        print("=================")
   
    def printAccount(self) :
        print("=================")
        print("고객번호 : {}".format(self.custId))
        print("고객명 : {}".format(self.custName)  )
        print("계좌번호 : {}".format(self.accountNumber))
        print("잔액 : {}".format(self.balance))
        print("=================")
              
              
    def  __str__(self) :
        return """================= 
                    고객번호 : {}  
                    고객명 : {}   
                    계좌번호 : {} 
                    잔액 : {}"
                  =================""".format(self.custId,self.custName, self.accountNumber, self.balance)
    @staticmethod
    def getMenuItem() :
        print("[Menu]")
        print("1. 입금")
        print("2. 출금")
        print("9. 종료")
        return int(input("=> Menu 선택 :"))
    
    @staticmethod
    def getAccount() :
        return int(input("금액 :"))
    
cust1 = Account("CUST01", "소지섭", "1-22-333", 100000)
print(cust1)
cust1.printAccount()
while True : 
    menu = Account.getMenuItem()
    if menu == 9 : 
        print("Bye~~")
        break
    elif menu == 1 : 
        balance = Account.getAccount()
        cust1.addBalance(balance)
    elif menu == 2 : 
        balance = Account.getAccount()
        cust1.substractBalance
